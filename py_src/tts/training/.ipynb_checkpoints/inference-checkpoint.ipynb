# %% [markdown]
# ## Tacotron 2 inference code
# Edit the variables **checkpoint_path** and **text** to match yours and run the entire code to generate plots of mel outputs, alignments and audio synthesis from the generated mel-spectrogram using Griffin-Lim.

# %% [markdown]
# #### Import libraries and setup matplotlib

# %%
import matplotlib
# %matplotlib inline
import matplotlib.pylab as plt

import IPython.display as ipd

import sys
sys.path.append('waveglow/')
import numpy as np
import torch

from hparams import create_hparams
from model import Tacotron2
from layers import TacotronSTFT, STFT
from audio_processing import griffin_lim
from train import load_model
from text import text_to_sequence
from denoiser import Denoiser
# Out:
# C:\Users\micha\solid-git\ojboj\audiobookproject\py_src\tts\training\plotting_utils.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\traitlets\config\application.py", line 664, in launch_instance
#     app.start()
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\asyncio\base_events.py", line 442, in run_forever
#     self._run_once()
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\asyncio\base_events.py", line 1462, in _run_once
#     handle._run()
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\tornado\gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\ipykernel\kernelbase.py", line 381, in dispatch_queue
#     yield self.process_one()
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\tornado\gen.py", line 250, in wrapper
#     runner = Runner(ctx_run, result, future, yielded)
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\tornado\gen.py", line 741, in __init__
#     self.ctx_run(self.run)
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\tornado\gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\tornado\gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\tornado\gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\ipykernel\kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\tornado\gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\ipykernel\ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\IPython\core\interactiveshell.py", line 2867, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\IPython\core\interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\IPython\core\interactiveshell.py", line 3072, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\IPython\core\interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\IPython\core\interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-1e40ea2a3544>", line 2, in <module>
#     get_ipython().run_line_magic('matplotlib', 'inline')
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\IPython\core\interactiveshell.py", line 2326, in run_line_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-109>", line 2, in matplotlib
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\IPython\core\magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\IPython\core\magics\pylab.py", line 99, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\IPython\core\interactiveshell.py", line 3431, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\IPython\core\pylabtools.py", line 322, in activate_matplotlib
#     plt.switch_backend(backend)
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\matplotlib\pyplot.py", line 229, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\matplotlib\__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "C:\Users\micha\anaconda3\envs\tt2-env-bb\lib\site-packages\matplotlib\backends\__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use("Agg")

# %%
def plot_data(data, figsize=(16, 4)):
    fig, axes = plt.subplots(1, len(data), figsize=figsize)
    for i in range(len(data)):
        axes[i].imshow(data[i], aspect='auto', origin='bottom', 
                       interpolation='none')

# %% [markdown]
# #### Setup hparams

# %%
hparams = create_hparams()
hparams.sampling_rate = 16000 # 22050
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %% [markdown]
# #### Load model from checkpoint

# %%
checkpoint_path = "outdir_ov/checkpoint_122999" # "tacotron2_statedict.pt"
model = load_model(hparams)
model.load_state_dict(torch.load(checkpoint_path)['state_dict'])
_ = model.cuda().eval().half()

# %% [markdown]
# #### Load WaveGlow for mel2audio synthesis and denoiser

# %%
waveglow_path = 'waveglow_swara_model_544000_16kHz.pt' # 'waveglow_256channels.pt'
waveglow = torch.load(waveglow_path)['model']
waveglow.cuda().eval().half()
for k in waveglow.convinv:
    k.float()
denoiser = Denoiser(waveglow)

# %% [markdown]
# #### Prepare text input

# %%
text_squarespace = "hello, today I want to talk to you about squarespace."
text_dino = "six hundred years ago last Tuesday, the dinosaurs died out."
text_train = "smiling with her spectacles in her hand and a measure of barley on her lap"
text_jeff = "my name jeff."

text = text_dino
sequence = np.array(text_to_sequence(text, ['english_cleaners']))[None, :]
sequence = torch.autograd.Variable(
    torch.from_numpy(sequence)).cuda().long()

# %% [markdown]
# #### Decode text input and plot results

# %%
mel_outputs, mel_outputs_postnet, _, alignments = model.inference(sequence)
plot_data((mel_outputs.float().data.cpu().numpy()[0],
           mel_outputs_postnet.float().data.cpu().numpy()[0],
           alignments.float().data.cpu().numpy()[0].T))

# %% [markdown]
# #### Synthesize audio from spectrogram using WaveGlow

# %%
with torch.no_grad():
    audio = waveglow.infer(mel_outputs_postnet, sigma=0.666)
ipd.Audio(audio[0].data.cpu().numpy(), rate=hparams.sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### (Optional) Remove WaveGlow bias

# %%
audio_denoised = denoiser(audio, strength=0.01)[:, 0]
ipd.Audio(audio_denoised.cpu().numpy(), rate=hparams.sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
